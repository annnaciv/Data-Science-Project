# %%
import pandas as pd

df = pd.read_csv('stress_detection.csv')
df.head(60)
# Out:
#     participant_id  day  ...  mobility_radius  mobility_distance
# 0                1    1  ...         1.145179           2.196851
# 1                1    2  ...         1.021133           0.737825
# 2                1    3  ...         0.478179           0.911673
# 3                1    4  ...         0.630549           3.911418
# 4                1    5  ...         0.254090           1.605132
# 5                1    6  ...         1.461828           3.927181
# 6                1    7  ...         1.017602           2.740476
# 7                1    8  ...         0.546391           4.715504
# 8                1    9  ...         0.475016           1.546705
# 9                1   10  ...         0.794373           2.206041
# 10               1   11  ...         0.481612           2.956367
# 11               1   12  ...         0.275873           4.164373
# 12               1   13  ...         0.951451           1.006892
# ...
